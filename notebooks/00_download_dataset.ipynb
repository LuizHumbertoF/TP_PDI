# %%
import kagglehub
import shutil
import os

src_path = kagglehub.dataset_download(
    "kmader/skin-cancer-mnist-ham10000"
)

dst_path = "dataset/raw"

os.makedirs(dst_path, exist_ok=True)

shutil.copytree(src_path, dst_path, dirs_exist_ok=True)

print("Dataset copiado para:", dst_path)
# Out:
# Downloading to /Users/yasminaraujo/.cache/kagglehub/datasets/kmader/skin-cancer-mnist-ham10000/2.archive...
# 100%|██████████| 5.20G/5.20G [07:00<00:00, 13.3MB/s]
# Extracting files...
# Dataset copiado para: dataset/raw
